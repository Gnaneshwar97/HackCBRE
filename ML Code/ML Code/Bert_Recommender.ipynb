# %%
import pandas as pd
import torch
from transformers import DistilBertTokenizer, DistilBertModel

# %%
import os
os.chdir('C:\\Users\\19452\\Desktop\\Challenge Data\\')

# %%
# 1. Loading data
property_insights_df = pd.read_csv("property_insights_extended.csv")
recommendation_users_df = pd.read_csv("recommendation_engine_users.csv")

# %%
# 2. Preprocessing Steps

# Aggregating User Activity based on Name and Dashboard
aggregated_activity = recommendation_users_df.groupby(['Name', 'Dashboard'])['User Activity'].sum().reset_index()
users_with_aggregated_activity = pd.merge(recommendation_users_df.drop(columns=['User Activity']), 
                                          aggregated_activity, 
                                          on=['Name', 'Dashboard'], 
                                          how='left')

# Extracting city name from the 'Property Address' column
property_insights_df['City'] = property_insights_df['Property Address'].str.split(',').str[-1].str.strip()

# %%
# Creating textual representation for users and property insights
users_with_aggregated_activity['text_representation'] = users_with_aggregated_activity['Role'] + ' ' + \
                                                        users_with_aggregated_activity['Business Line'] + ' ' + \
                                                        users_with_aggregated_activity['Location'] + ' ' + \
                                                        users_with_aggregated_activity['Client'] + ' ' + \
                                                        users_with_aggregated_activity['Dashboard']

property_insights_df['text_representation'] = property_insights_df['City'] + ' ' + \
                                             property_insights_df['Insight 1'] + ' ' + \
                                             property_insights_df['Insight 2'] + ' ' + \
                                             property_insights_df['Driver']

# %%
# Applying weightings to the textual representations
users_with_aggregated_activity['weighted_representation'] = users_with_aggregated_activity.apply(lambda x: (x['text_representation'] + ' ') * x['User Activity'], axis=1)
criticality_weights = {'Low': 1, 'Medium': 2, 'High': 3, 'Critical': 4}
property_insights_df['Criticality_Weight'] = property_insights_df['Criticality'].map(criticality_weights)
property_insights_df['weighted_representation'] = property_insights_df.apply(lambda x: (x['text_representation'] + ' ') * x['Criticality_Weight'], axis=1)

# %%
# Load DistilBERT tokenizer and model
tokenizer = DistilBertTokenizer.from_pretrained('distilbert-base-uncased')
model = DistilBertModel.from_pretrained('distilbert-base-uncased')

# Check if GPU is available and if so, set the model to use GPU
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = model.to(device)
model.eval()
# Out:
# DistilBertModel(
#   (embeddings): Embeddings(
#     (word_embeddings): Embedding(30522, 768, padding_idx=0)
#     (position_embeddings): Embedding(512, 768)
#     (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (transformer): Transformer(
#     (layer): ModuleList(
#       (0-5): 6 x TransformerBlock(
#         (attention): MultiHeadSelfAttention(
#           (dropout): Dropout(p=0.1, inplace=False)
#           (q_lin): Linear(in_features=768, out_features=768, bias=True)
#           (k_lin): Linear(in_features=768, out_features=768, bias=True)
#           (v_lin): Linear(in_features=768, out_features=768, bias=True)
#           (out_lin): Linear(in_features=768, out_features=768, bias=True)
#         )
#         (sa_layer_norm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#         (ffn): FFN(
#           (dropout): Dropout(p=0.1, inplace=False)
#           (lin1): Linear(in_features=768, out_features=3072, bias=True)
#           (lin2): Linear(in_features=3072, out_features=768, bias=True)
#           (activation): GELUActivation()
#         )
#         (output_layer_norm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#       )
#     )
#   )
# )

# %%
# Tokenize the textual representations without truncation
tokenized_users = tokenizer(users_with_aggregated_activity['weighted_representation'].tolist(), truncation=False, padding=False, return_length=True)
tokenized_insights = tokenizer(property_insights_df['weighted_representation'].tolist(), truncation=False, padding=False, return_length=True)

# Determine the maximum length from both datasets
max_length_users = max(tokenized_users['length'])
max_length_insights = max(tokenized_insights['length'])

max_length = max(max_length_users, max_length_insights)
print(max_length)
# Out:
# Token indices sequence length is longer than the specified maximum sequence length for this model (1058 > 512). Running this sequence through the model will result in indexing errors
# 4201

# %%
def get_distilbert_embeddings(texts, batch_size=32):
    embeddings = []
    for i in range(0, len(texts), batch_size):
        batch_texts = texts[i:i+batch_size]
        tokens = tokenizer(batch_texts, return_tensors="pt", padding=True, truncation=True, max_length=512)
        tokens = tokens.to(device)
        with torch.no_grad():
            batch_embeddings = model(**tokens).last_hidden_state.mean(dim=1).cpu().numpy()
        embeddings.extend(batch_embeddings)
    return embeddings

# Generating embeddings in batches
user_embeddings = get_distilbert_embeddings(users_with_aggregated_activity['weighted_representation'].tolist())
insight_embeddings = get_distilbert_embeddings(property_insights_df['weighted_representation'].tolist())

# %%
def filter_user_data_by_name(name):
    """
    Given a name, return the user data for that particular individual.
    """
    return users_with_aggregated_activity[users_with_aggregated_activity['Name'] == name]

def extract_client_location(user_data):
    """
    Extract the 'Client' and 'Location' details from the user data.
    """
    client = user_data['Client'].iloc[0]
    location = user_data['Location'].iloc[0]
    return client, location

def filter_property_insights_by_client_location(client, location):
    """
    Use the provided 'Client' and 'Location' details to filter the property insights data.
    """
    client_filter = property_insights_df['Account'] == client
    location_filter = property_insights_df['City'] == location
    return property_insights_df[client_filter & location_filter]

# Testing steps 1-3:
user_name_to_query = "Bradley Jenkins"
user_data = filter_user_data_by_name(user_name_to_query)
client, location = extract_client_location(user_data)
filtered_property_insights = filter_property_insights_by_client_location(client, location)

print(filtered_property_insights)
# Out:
#                        Property Address      Insight 1  \
# 29            8703 James Ways St, Miami    Work Orders
# 53       7211 Jennings Canyon St, Miami    Work Orders
# 131    5661 Christopher Knoll St, Miami   Energy Usage
# 150       6280 Austin Squares St, Miami         Leases
# 171            1462 Boyd Mill St, Miami         Leases
# 208         2043 Lozano Crest St, Miami        Budgets
# 314         5975 Wheeler Pike St, Miami         Leases
# 323         6169 Fischer Camp St, Miami     Compliance
# 416        8300 Jones Village St, Miami    Work Orders
# 455        2504 Richard Cliff St, Miami        Budgets
# 464     4799 David Throughway St, Miami         Leases
# 741         3902 Ball Corners St, Miami         Leases
# 750      6674 Daniel Parkways St, Miami     Compliance
# 756           3709 Chris Glen St, Miami   Energy Usage
# 786   4735 Gregory Throughway St, Miami   Energy Usage
# 825          4485 Eric Estate St, Miami     Compliance
# 884      5166 Adrienne Courts St, Miami    Work Orders
# 935          7054 Gordon Path St, Miami         Leases
# 1064    9647 Anthony Mountain St, Miami   Energy Usage
# 1086        5919 Jesse Harbor St, Miami     Compliance
# 1184     1164 Howard Crescent St, Miami  Accessibility
# 1263      275 Washington Ford St, Miami    Work Orders
#
#                      Insight 2                               Driver  \
# 29                    Reactive           Completion Rates below 50%
# 53             Completion Rate           Completion Rates below 50%
# 131          Energy Efficiency  High energy usage during peak hours
# 150                  Occupancy                    Low renewal rates
# 171                   Expiring       High number of expiring leases
# 208          Budget Compliance          Energy Costs above 15% mean
# 314               Renewal Rate       High number of expiring leases
# 323           Compliance Score    Multiple non-compliance incidents
# 416            Completion Rate           Completion Rates below 50%
# 455       Energy Cost Variance          Energy Costs above 15% mean
# 464               Renewal Rate                    Low renewal rates
# 741                   Expiring                    Low renewal rates
# 750         Regulatory Updates          Upcoming regulatory changes
# 756          Energy Efficiency  High energy usage during peak hours
# 786                 Peak Hours  High energy usage during peak hours
# 825   Non-Compliance Incidents    Multiple non-compliance incidents
# 884               Preventative  High number of reactive work orders
# 935                  Occupancy                    Low renewal rates
# 1064                 Off-Hours                Low energy efficiency
# 1086          Compliance Score          Upcoming regulatory changes
# 1184           Elevator Status              Non-ADA compliant areas
# 1263                  Reactive  High number of reactive work orders
#
#                  Account Criticality   City  \
# 29    Skyline Properties         Low  Miami
# 53    Skyline Properties    Critical  Miami
# 131   Skyline Properties    Critical  Miami
# 150   Skyline Properties      Medium  Miami
# 171   Skyline Properties      Medium  Miami
# 208   Skyline Properties    Critical  Miami
# 314   Skyline Properties    Critical  Miami
# 323   Skyline Properties         Low  Miami
# 416   Skyline Properties         Low  Miami
# 455   Skyline Properties    Critical  Miami
# 464   Skyline Properties        High  Miami
# 741   Skyline Properties         Low  Miami
# 750   Skyline Properties    Critical  Miami
# 756   Skyline Properties        High  Miami
# 786   Skyline Properties         Low  Miami
# 825   Skyline Properties         Low  Miami
# 884   Skyline Properties         Low  Miami
# 935   Skyline Properties      Medium  Miami
# 1064  Skyline Properties         Low  Miami
# 1086  Skyline Properties    Critical  Miami
# 1184  Skyline Properties         Low  Miami
# 1263  Skyline Properties    Critical  Miami
#
#                                     text_representation  Criticality_Weight  \
# 29    Miami Work Orders Reactive Completion Rates be...                   1
# 53    Miami Work Orders Completion Rate Completion R...                   4
# 131   Miami Energy Usage Energy Efficiency High ener...                   4
# 150            Miami Leases Occupancy Low renewal rates                   2
# 171   Miami Leases Expiring High number of expiring ...                   2
# 208   Miami Budgets Budget Compliance Energy Costs a...                   4
# 314   Miami Leases Renewal Rate High number of expir...                   4
# 323   Miami Compliance Compliance Score Multiple non...                   1
# 416   Miami Work Orders Completion Rate Completion R...                   1
# 455   Miami Budgets Energy Cost Variance Energy Cost...                   4
# 464         Miami Leases Renewal Rate Low renewal rates                   3
# 741             Miami Leases Expiring Low renewal rates                   1
# 750   Miami Compliance Regulatory Updates Upcoming r...                   4
# 756   Miami Energy Usage Energy Efficiency High ener...                   3
# 786   Miami Energy Usage Peak Hours High energy usag...                   1
# 825   Miami Compliance Non-Compliance Incidents Mult...                   1
# 884   Miami Work Orders Preventative High number of ...                   1
# 935            Miami Leases Occupancy Low renewal rates                   2
# 1064  Miami Energy Usage Off-Hours Low energy effici...                   1
# 1086  Miami Compliance Compliance Score Upcoming reg...                   4
# 1184  Miami Accessibility Elevator Status Non-ADA co...                   1
# 1263  Miami Work Orders Reactive High number of reac...                   4
#
#                                 weighted_representation
# 29    Miami Work Orders Reactive Completion Rates be...
# 53    Miami Work Orders Completion Rate Completion R...
# 131   Miami Energy Usage Energy Efficiency High ener...
# 150   Miami Leases Occupancy Low renewal rates Miami...
# 171   Miami Leases Expiring High number of expiring ...
# 208   Miami Budgets Budget Compliance Energy Costs a...
# 314   Miami Leases Renewal Rate High number of expir...
# 323   Miami Compliance Compliance Score Multiple non...
# 416   Miami Work Orders Completion Rate Completion R...
# 455   Miami Budgets Energy Cost Variance Energy Cost...
# 464   Miami Leases Renewal Rate Low renewal rates Mi...
# 741            Miami Leases Expiring Low renewal rates
# 750   Miami Compliance Regulatory Updates Upcoming r...
# 756   Miami Energy Usage Energy Efficiency High ener...
# 786   Miami Energy Usage Peak Hours High energy usag...
# 825   Miami Compliance Non-Compliance Incidents Mult...
# 884   Miami Work Orders Preventative High number of ...
# 935   Miami Leases Occupancy Low renewal rates Miami...
# 1064  Miami Energy Usage Off-Hours Low energy effici...
# 1086  Miami Compliance Compliance Score Upcoming reg...
# 1184  Miami Accessibility Elevator Status Non-ADA co...
# 1263  Miami Work Orders Reactive High number of reac...

# %%
# Load the Role-Insight Mapping
role_insight_df = pd.read_csv("roles_duties_and_insights.csv")
role_insight_mapping = pd.Series(role_insight_df['Relevant Insights'].str.split(', ').tolist(), index=role_insight_df['Role']).to_dict()

# %%
def generate_insight_based_on_criticality(location, insight1, insight2, driver, criticality):
    # Base sentences for different criticality levels
    criticality_sentences = {
        'Critical': f"There's a critical concern regarding '{insight1}'-'{insight2}' in {location}. These are unusually high, primarily influenced by '{driver}'. Immediate attention is required.",
        'High': f"It's important to note that '{insight1}'-'{insight2}' in {location} are above expected levels, majorly due to '{driver}'. It's recommended to address this soon.",
        'Medium': f"'{insight1}'-'{insight2}' in {location} have been observed to be slightly higher than usual, influenced by '{driver}'. This should be monitored.",
        'Low': f"'{insight1}'-'{insight2}' in {location} are in line with expectations but are influenced by '{driver}'. No immediate action is required, but it's good to be aware."
    }
    
    return criticality_sentences.get(criticality, "Invalid criticality level")

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
def get_recommendations_for_user(user_name, num_recommendations=5):
    # Fetch user data
    user_data = filter_user_data_by_name(user_name)
    client, location = extract_client_location(user_data)
    
    # Filter insights by client and location
    filtered_insights = filter_property_insights_by_client_location(client, location)
    
    # Compute similarity scores
    user_index = user_data.index[0]
    insight_indices = filtered_insights.index.tolist()
    similarity_scores = cosine_similarity([user_embeddings[user_index]], [insight_embeddings[i] for i in insight_indices])[0]
    
    # Adjust similarity scores based on role-insight mapping and user activity
    user_role = user_data['Role'].iloc[0]
    relevant_insights = role_insight_mapping.get(user_role, [])
    dashboard_activity = dict(zip(user_data['Dashboard'].tolist(), user_data['User Activity'].tolist()))
    
    for idx, insight in filtered_insights.iterrows():
        # Adjust based on role-insight mapping
        if insight['Insight 1'] not in relevant_insights and insight['Insight 2'] not in relevant_insights:
            similarity_scores[insight_indices.index(idx)] *= 0.5  # Reduce the score by half for non-relevant insights
        
        # Boost based on user activity on dashboards
        for dashboard, activity in dashboard_activity.items():
            if insight['Insight 1'] == dashboard or insight['Insight 2'] == dashboard or insight['Driver'] == dashboard:
                similarity_scores[insight_indices.index(idx)] += activity * 2  # Double boosting for direct matches
    
    # Convert criticality to numeric for sorting
    criticality_map = {'Low': 1, 'Medium': 2, 'High': 3, 'Critical': 4}
    criticality_scores = filtered_insights['Criticality'].map(criticality_map).tolist()
    
    # Rank insights by similarity and then by criticality
    top_indices = sorted(range(len(similarity_scores)), key=lambda i: (similarity_scores[i], criticality_scores[i]), reverse=True)[:num_recommendations]
    
    recommendations = []
    for idx in top_indices:
        insight_data = filtered_insights.iloc[idx]
        recommendation_sentence = generate_insight_based_on_criticality(
            insight_data['City'], 
            insight_data['Insight 1'], 
            insight_data['Insight 2'], 
            insight_data['Driver'], 
            insight_data['Criticality']
        )
        recommendations.append(recommendation_sentence)
    
    return recommendations

# %%
# Test the function for Bradley Jenkins
user_name_to_query = "Bradley Jenkins"
recommendations_for_user = get_recommendations_for_user(user_name_to_query)
print(f"Top recommendations for {user_name_to_query}:")
print("\n".join(recommendations_for_user))
# Out:
# Top recommendations for Bradley Jenkins:
# There's a critical concern regarding 'Leases'-'Renewal Rate' in Miami. These are unusually high, primarily influenced by 'High number of expiring leases'. Immediate attention is required.
# It's important to note that 'Leases'-'Renewal Rate' in Miami are above expected levels, majorly due to 'Low renewal rates'. It's recommended to address this soon.
# There's a critical concern regarding 'Compliance'-'Regulatory Updates' in Miami. These are unusually high, primarily influenced by 'Upcoming regulatory changes'. Immediate attention is required.
# There's a critical concern regarding 'Energy Usage'-'Energy Efficiency' in Miami. These are unusually high, primarily influenced by 'High energy usage during peak hours'. Immediate attention is required.
# There's a critical concern regarding 'Budgets'-'Budget Compliance' in Miami. These are unusually high, primarily influenced by 'Energy Costs above 15% mean'. Immediate attention is required.

# %%
user_name_to_query = "Charles Potts"
recommendations_for_user = get_recommendations_for_user(user_name_to_query)
print(f"Top recommendations for {user_name_to_query}:")
print((type(recommendations_for_user)))
# Out:
# Top recommendations for Charles Potts:
# <class 'list'>

# %%
import json
res = {}
for ind in recommendation_users_df.index:
    user_name_to_query = recommendation_users_df['Name'][ind]
    recommendations_for_user = get_recommendations_for_user(user_name_to_query)
    #inter_jsonObj = json.dumps(recommendations_for_user,indent=4)
    res[user_name_to_query] = recommendations_for_user;

# %%
jsonObj = json.dumps(res,indent = 4)
print(jsonObj)

with open("sample.json", "w") as outfile: 
    json.dump(res, outfile)
# Out:
# {
#     "Charles Potts": [
#         "There's a critical concern regarding 'Budgets'-'Energy Cost Variance' in Boston. These are unusually high, primarily influenced by 'Janitorial Budget above 20% mean'. Immediate attention is required.",
#         "There's a critical concern regarding 'Work Orders'-'Preventative' in Boston. These are unusually high, primarily influenced by 'High number of reactive work orders'. Immediate attention is required.",
#         "It's important to note that 'Budgets'-'Janitorial Expenses 10% Over Mean' in Boston are above expected levels, majorly due to 'Janitorial Budget above 20% mean'. It's recommended to address this soon.",
#         "There's a critical concern regarding 'Budgets'-'Budget Compliance' in Boston. These are unusually high, primarily influenced by 'Energy Costs above 15% mean'. Immediate attention is required.",
#         "There's a critical concern regarding 'Safety Incidents'-'Fire Safety' in Boston. These are unusually high, primarily influenced by 'Hazardous material spill'. Immediate attention is required."
#     ],
#     "Shannon Rose": [
#         "There's a critical concern regarding 'Work Orders'-'Completion Rate' in Atlanta. These are unusually high, primarily influenced by 'Completion Rates below 50%'. Immediate attention is required.",
#         "It's important to note that 'Budgets'-'Janitorial Expenses 10% Over Mean' in Atlanta are above expected levels, majorly due to 'Janitorial Budget above 20% mean'. It's recommended to address this soon.",
#         "It's important to note that 'Budgets'-'Janitorial Expenses 10% Over Mean' in Atlanta are above expected levels, majorly due to 'Energy Costs above 15% mean'. It's recommended to address this soon.",
#         "There's a critical concern regarding 'Compliance'-'Compliance Score' in Atlanta. These are unusually high, primarily influenced by 'Upcoming regulatory changes'. Immediate attention is required.",
#         "It's important to note that 'Work Orders'-'Reactive' in Atlanta are above expected levels, majorly due to 'Completion Rates below 50%'. It's recommended to address this soon."
#     ],
#     "Kristen Daugherty": [
#         "There's a critical concern regarding 'Work Orders'-'Completion Rate' in Dallas. These are unusually high, primarily influenced by 'High number of reactive work orders'. Immediate attention is required.",
#         "It's important to note that 'Budgets'-'Janitorial Expenses 10% Over Mean' in Dallas are above expected levels, majorly due to 'Energy Costs above 15% mean'. It's recommended to address this soon.",
#         "'Budgets'-'Janitorial Expenses 10% Over Mean' in Dallas have been observed to be slightly higher than usual, influenced by 'Janitorial Budget above 20% mean'. This should be monitored.",
#         "There's a critical concern regarding 'Energy Usage'-'Off-Hours' in Dallas. These are unusually high, primarily influenced by 'Low energy efficiency'. Immediate attention is required.",
#         "It's important to note that 'Budgets'-'Budget Compliance' in Dallas are above expected levels, majorly due to 'Energy Costs above 15% mean'. It's recommended to address this soon."
#     ],
#     "Michael Patrick": [
#         "'Energy Usage'-'Energy Efficiency' in Los Angeles are in line with expectations but are influenced by 'Low energy efficiency'. No immediate action is required, but it's good to be aware.",
#         "'Energy Usage'-'Off-Hours' in Los Angeles are in line with expectations but are influenced by 'Low energy efficiency'. No immediate action is required, but it's good to be aware.",
#         "'Leases'-'Renewal Rate' in Los Angeles are in line with expectations but are influenced by 'High number of expiring leases'. No immediate action is required, but it's good to be aware.",
#         "'Leases'-'Renewal Rate' in Los Angeles are in line with expectations but are influenced by 'High number of expiring leases'. No immediate action is required, but it's good to be aware.",
#         "'Compliance'-'Regulatory Updates' in Los Angeles have been observed to be slightly higher than usual, influenced by 'Upcoming regulatory changes'. This should be monitored."
#     ],
#     "Derrick Stephenson": [
#         "It's important to note that 'Leases'-'Occupancy' in San Francisco are above expected levels, majorly due to 'High number of expiring leases'. It's recommended to address this soon.",
#         "There's a critical concern regarding 'Leases'-'Expiring' in San Francisco. These are unusually high, primarily influenced by 'High number of expiring leases'. Immediate attention is required.",
#         "It's important to note that 'Work Orders'-'Reactive' in San Francisco are above expected levels, majorly due to 'Completion Rates below 50%'. It's recommended to address this soon.",
#         "'Leases'-'Occupancy' in San Francisco have been observed to be slightly higher than usual, influenced by 'High number of expiring leases'. This should be monitored.",
#         "'Tenant Satisfaction'-'Lease Satisfaction' in San Francisco have been observed to be slightly higher than usual, influenced by 'Multiple noise complaints'. This should be monitored."
#     ],
#     "Mitchell Crawford": [
#         "There's a critical concern regarding 'Energy Usage'-'Peak Hours' in San Francisco. These are unusually high, primarily influenced by 'High energy usage during peak hours'. Immediate attention is required.",
#         "It's important to note that 'Budgets'-'Janitorial Expenses 10% Over Mean' in San Francisco are above expected levels, majorly due to 'Janitorial Budget above 20% mean'. It's recommended to address this soon.",
#         "There's a critical concern regarding 'Work Orders'-'Preventative' in San Francisco. These are unusually high, primarily influenced by 'Completion Rates below 50%'. Immediate attention is required.",
#         "It's important to note that 'Energy Usage'-'Energy Efficiency' in San Francisco are above expected levels, majorly due to 'High energy usage during peak hours'. It's recommended to address this soon.",
#         "There's a critical concern regarding 'Compliance'-'Non-Compliance Incidents' in San Francisco. These are unusually high, primarily influenced by 'Upcoming regulatory changes'. Immediate attention is required."
#     ],
#     "Dr. Justin Nguyen": [
#         "There's a critical concern regarding 'Budgets'-'Budget Compliance' in Seattle. These are unusually high, primarily influenced by 'Energy Costs above 15% mean'. Immediate attention is required.",
#         "It's important to note that 'Budgets'-'Janitorial Expenses 10% Over Mean' in Seattle are above expected levels, majorly due to 'Energy Costs above 15% mean'. It's recommended to address this soon.",
#         "There's a critical concern regarding 'Compliance'-'Non-Compliance Incidents' in Seattle. These are unusually high, primarily influenced by 'Multiple non-compliance incidents'. Immediate attention is required.",
#         "There's a critical concern regarding 'Energy Usage'-'Peak Hours' in Seattle. These are unusually high, primarily influenced by 'High energy usage during peak hours'. Immediate attention is required.",
#         "'Work Orders'-'Completion Rate' in Seattle have been observed to be slightly higher than usual, influenced by 'High number of reactive work orders'. This should be monitored."
#     ],
#     "Allison Dominguez DVM": [
#         "There's a critical concern regarding 'Work Orders'-'Reactive' in Los Angeles. These are unusually high, primarily influenced by 'Completion Rates below 50%'. Immediate attention is required.",
#         "There's a critical concern regarding 'Budgets'-'Energy Cost Variance' in Los Angeles. These are unusually high, primarily influenced by 'Janitorial Budget above 20% mean'. Immediate attention is required.",
#         "There's a critical concern regarding 'Budgets'-'Janitorial Expenses 10% Over Mean' in Los Angeles. These are unusually high, primarily influenced by 'Janitorial Budget above 20% mean'. Immediate attention is required.",
#         "It's important to note that 'Budgets'-'Janitorial Expenses 10% Over Mean' in Los Angeles are above expected levels, majorly due to 'Energy Costs above 15% mean'. It's recommended to address this soon.",
#         "It's important to note that 'Compliance'-'Regulatory Updates' in Los Angeles are above expected levels, majorly due to 'Multiple non-compliance incidents'. It's recommended to address this soon."
#     ],
#     "Susan Simon": [
#         "There's a critical concern regarding 'Work Orders'-'Completion Rate' in Los Angeles. These are unusually high, primarily influenced by 'High number of reactive work orders'. Immediate attention is required.",
#         "There's a critical concern regarding 'Leases'-'Occupancy' in Los Angeles. These are unusually high, primarily influenced by 'High number of expiring leases'. Immediate attention is required.",
#         "There's a critical concern regarding 'Energy Usage'-'Energy Efficiency' in Los Angeles. These are unusually high, primarily influenced by 'High energy usage during peak hours'. Immediate attention is required.",
#         "There's a critical concern regarding 'Budgets'-'Energy Cost Variance' in Los Angeles. These are unusually high, primarily influenced by 'Energy Costs above 15% mean'. Immediate attention is required.",
#         "There's a critical concern regarding 'Compliance'-'Regulatory Updates' in Los Angeles. These are unusually high, primarily influenced by 'Multiple non-compliance incidents'. Immediate attention is required."
#     ],
#     "Seth Herrera": [
#         "It's important to note that 'Budgets'-'Janitorial Expenses 10% Over Mean' in Seattle are above expected levels, majorly due to 'Energy Costs above 15% mean'. It's recommended to address this soon.",
#         "There's a critical concern regarding 'Compliance'-'Non-Compliance Incidents' in Seattle. These are unusually high, primarily influenced by 'Multiple non-compliance incidents'. Immediate attention is required.",
#         "There's a critical concern regarding 'Budgets'-'Budget Compliance' in Seattle. These are unusually high, primarily influenced by 'Energy Costs above 15% mean'. Immediate attention is required.",
#         "There's a critical concern regarding 'Energy Usage'-'Peak Hours' in Seattle. These are unusually high, primarily influenced by 'High energy usage during peak hours'. Immediate attention is required.",
#         "'Work Orders'-'Completion Rate' in Seattle have been observed to be slightly higher than usual, influenced by 'High number of reactive work orders'. This should be monitored."
#     ],
#     "David James": [
#         "It's important to note that 'Compliance'-'Non-Compliance Incidents' in Boston are above expected levels, majorly due to 'Upcoming regulatory changes'. It's recommended to address this soon.",
#         "It's important to note that 'Energy Usage'-'Energy Efficiency' in Boston are above expected levels, majorly due to 'High energy usage during peak hours'. It's recommended to address this soon.",
#         "It's important to note that 'Leases'-'Expiring' in Boston are above expected levels, majorly due to 'High number of expiring leases'. It's recommended to address this soon.",
#         "It's important to note that 'Work Orders'-'Completion Rate' in Boston are above expected levels, majorly due to 'Completion Rates below 50%'. It's recommended to address this soon.",
#         "'Energy Usage'-'Energy Efficiency' in Boston have been observed to be slightly higher than usual, influenced by 'High energy usage during peak hours'. This should be monitored."
#     ],
#     "Robert Valdez": [
#         "There's a critical concern regarding 'Leases'-'Renewal Rate' in Miami. These are unusually high, primarily influenced by 'High number of expiring leases'. Immediate attention is required.",
#         "There's a critical concern regarding 'Energy Usage'-'Energy Efficiency' in Miami. These are unusually high, primarily influenced by 'High energy usage during peak hours'. Immediate attention is required.",
#         "It's important to note that 'Budgets'-'Energy Cost Variance' in Miami are above expected levels, majorly due to 'Janitorial Budget above 20% mean'. It's recommended to address this soon.",
#         "There's a critical concern regarding 'Budgets'-'Budget Compliance' in Miami. These are unusually high, primarily influenced by 'Energy Costs above 15% mean'. Immediate attention is required.",
#         "There's a critical concern regarding 'Energy Usage'-'Peak Hours' in Miami. These are unusually high, primarily influenced by 'Low energy efficiency'. Immediate attention is required."
#     ],
#     "Carl Ramirez": [
#         "There's a critical concern regarding 'Energy Usage'-'Energy Efficiency' in Miami. These are unusually high, primarily influenced by 'Low energy efficiency'. Immediate attention is required.",
#         "'Energy Usage'-'Energy Efficiency' in Miami have been observed to be slightly higher than usual, influenced by 'High energy usage during peak hours'. This should be monitored.",
#         "'Energy Usage'-'Energy Efficiency' in Miami are in line with expectations but are influenced by 'Low energy efficiency'. No immediate action is required, but it's good to be aware.",
#         "There's a critical concern regarding 'Energy Usage'-'Off-Hours' in Miami. These are unusually high, primarily influenced by 'High energy usage during peak hours'. Immediate attention is required.",
#         "It's important to note that 'Energy Usage'-'Off-Hours' in Miami are above expected levels, majorly due to 'Low energy efficiency'. It's recommended to address this soon."
#     ],
#     "Dillon Wiley": [
#         "There's a critical concern regarding 'Leases'-'Renewal Rate' in New York. These are unusually high, primarily influenced by 'High number of expiring leases'. Immediate attention is required.",
#         "It's important to note that 'Budgets'-'Janitorial Expenses 10% Over Mean' in New York are above expected levels, majorly due to 'Janitorial Budget above 20% mean'. It's recommended to address this soon.",
#         "It's important to note that 'Leases'-'Occupancy' in New York are above expected levels, majorly due to 'Low renewal rates'. It's recommended to address this soon.",
#         "It's important to note that 'Leases'-'Expiring' in New York are above expected levels, majorly due to 'High number of expiring leases'. It's recommended to address this soon.",
#         "There's a critical concern regarding 'Work Orders'-'Preventative' in New York. These are unusually high, primarily influenced by 'Completion Rates below 50%'. Immediate attention is required."
#     ],
#     "Veronica Garza": [
#         "It's important to note that 'Budgets'-'Energy Cost Variance' in Seattle are above expected levels, majorly due to 'Janitorial Budget above 20% mean'. It's recommended to address this soon.",
#         "It's important to note that 'Budgets'-'Janitorial Expenses 10% Over Mean' in Seattle are above expected levels, majorly due to 'Janitorial Budget above 20% mean'. It's recommended to address this soon.",
#         "There's a critical concern regarding 'Leases'-'Occupancy' in Seattle. These are unusually high, primarily influenced by 'High number of expiring leases'. Immediate attention is required.",
#         "There's a critical concern regarding 'Work Orders'-'Completion Rate' in Seattle. These are unusually high, primarily influenced by 'High number of reactive work orders'. Immediate attention is required.",
#         "It's important to note that 'Leases'-'Occupancy' in Seattle are above expected levels, majorly due to 'Low renewal rates'. It's recommended to address this soon."
#     ],
#     "Mrs. Teresa Dorsey MD": [
#         "There's a critical concern regarding 'Budgets'-'Janitorial Expenses 10% Over Mean' in New York. These are unusually high, primarily influenced by 'Energy Costs above 15% mean'. Immediate attention is required.",
#         "There's a critical concern regarding 'Energy Usage'-'Energy Efficiency' in New York. These are unusually high, primarily influenced by 'High energy usage during peak hours'. Immediate attention is required.",
#         "There's a critical concern regarding 'Leases'-'Renewal Rate' in New York. These are unusually high, primarily influenced by 'High number of expiring leases'. Immediate attention is required.",
#         "It's important to note that 'Leases'-'Renewal Rate' in New York are above expected levels, majorly due to 'High number of expiring leases'. It's recommended to address this soon.",
#         "There's a critical concern regarding 'Compliance'-'Regulatory Updates' in New York. These are unusually high, primarily influenced by 'Multiple non-compliance incidents'. Immediate attention is required."
#     ],
#     "Patricia Cain": [
#         "It's important to note that 'Energy Usage'-'Energy Efficiency' in Dallas are above expected levels, majorly due to 'High energy usage during peak hours'. It's recommended to address this soon.",
#         "'Energy Usage'-'Peak Hours' in Dallas have been observed to be slightly higher than usual, influenced by 'High energy usage during peak hours'. This should be monitored.",
#         "'Energy Usage'-'Peak Hours' in Dallas are in line with expectations but are influenced by 'Low energy efficiency'. No immediate action is required, but it's good to be aware.",
#         "It's important to note that 'Budgets'-'Janitorial Expenses 10% Over Mean' in Dallas are above expected levels, majorly due to 'Janitorial Budget above 20% mean'. It's recommended to address this soon.",
#         "There's a critical concern regarding 'Leases'-'Occupancy' in Dallas. These are unusually high, primarily influenced by 'Low renewal rates'. Immediate attention is required."
#     ],
#     "Zachary Woods": [
#         "There's a critical concern regarding 'Energy Usage'-'Energy Efficiency' in Atlanta. These are unusually high, primarily influenced by 'High energy usage during peak hours'. Immediate attention is required.",
#         "There's a critical concern regarding 'Work Orders'-'Completion Rate' in Atlanta. These are unusually high, primarily influenced by 'Completion Rates below 50%'. Immediate attention is required.",
#         "There's a critical concern regarding 'Leases'-'Renewal Rate' in Atlanta. These are unusually high, primarily influenced by 'High number of expiring leases'. Immediate attention is required.",
#         "'Budgets'-'Janitorial Expenses 10% Over Mean' in Atlanta have been observed to be slightly higher than usual, influenced by 'Energy Costs above 15% mean'. This should be monitored.",
#         "It's important to note that 'Leases'-'Occupancy' in Atlanta are above expected levels, majorly due to 'High number of expiring leases'. It's recommended to address this soon."
#     ],
#     "Shannon Perkins": [
#         "There's a critical concern regarding 'Budgets'-'Energy Cost Variance' in Miami. These are unusually high, primarily influenced by 'Janitorial Budget above 20% mean'. Immediate attention is required.",
#         "It's important to note that 'Budgets'-'Janitorial Expenses 10% Over Mean' in Miami are above expected levels, majorly due to 'Energy Costs above 15% mean'. It's recommended to address this soon.",
#         "There's a critical concern regarding 'Compliance'-'Non-Compliance Incidents' in Miami. These are unusually high, primarily influenced by 'Multiple non-compliance incidents'. Immediate attention is required.",
#         "There's a critical concern regarding 'Leases'-'Expiring' in Miami. These are unusually high, primarily influenced by 'High number of expiring leases'. Immediate attention is required.",
#         "'Budgets'-'Janitorial Expenses 10% Over Mean' in Miami have been observed to be slightly higher than usual, influenced by 'Energy Costs above 15% mean'. This should be monitored."
#     ],
#     "Joseph Richardson": [
#         "There's a critical concern regarding 'Budgets'-'Janitorial Expenses 10% Over Mean' in New York. These are unusually high, primarily influenced by 'Energy Costs above 15% mean'. Immediate attention is required.",
#         "It's important to note that 'Leases'-'Renewal Rate' in New York are above expected levels, majorly due to 'High number of expiring leases'. It's recommended to address this soon.",
#         "'Tenant Satisfaction'-'Lease Satisfaction' in New York have been observed to be slightly higher than usual, influenced by 'Multiple noise complaints'. This should be monitored.",
#         "There's a critical concern regarding 'Compliance'-'Regulatory Updates' in New York. These are unusually high, primarily influenced by 'Multiple non-compliance incidents'. Immediate attention is required.",
#         "There's a critical concern regarding 'Compliance'-'Regulatory Updates' in New York. These are unusually high, primarily influenced by 'Multiple non-compliance incidents'. Immediate attention is required."
#     ],
#     "Mrs. Julia Carter": [
#         "There's a critical concern regarding 'Leases'-'Occupancy' in Houston. These are unusually high, primarily influenced by 'High number of expiring leases'. Immediate attention is required.",
#         "There's a critical concern regarding 'Energy Usage'-'Peak Hours' in Houston. These are unusually high, primarily influenced by 'High energy usage during peak hours'. Immediate attention is required.",
#         "There's a critical concern regarding 'Energy Usage'-'Energy Efficiency' in Houston. These are unusually high, primarily influenced by 'High energy usage during peak hours'. Immediate attention is required.",
#         "There's a critical concern regarding 'Work Orders'-'Reactive' in Houston. These are unusually high, primarily influenced by 'High number of reactive work orders'. Immediate attention is required.",
#         "There's a critical concern regarding 'Work Orders'-'Reactive' in Houston. These are unusually high, primarily influenced by 'Completion Rates below 50%'. Immediate attention is required."
#     ],
#     "Alexandra Wagner": [
#         "It's important to note that 'Compliance'-'Non-Compliance Incidents' in Boston are above expected levels, majorly due to 'Upcoming regulatory changes'. It's recommended to address this soon.",
#         "It's important to note that 'Energy Usage'-'Energy Efficiency' in Boston are above expected levels, majorly due to 'High energy usage during peak hours'. It's recommended to address this soon.",
#         "It's important to note that 'Leases'-'Expiring' in Boston are above expected levels, majorly due to 'High number of expiring leases'. It's recommended to address this soon.",
#         "'Energy Usage'-'Energy Efficiency' in Boston have been observed to be slightly higher than usual, influenced by 'High energy usage during peak hours'. This should be monitored.",
#         "It's important to note that 'Work Orders'-'Completion Rate' in Boston are above expected levels, majorly due to 'Completion Rates below 50%'. It's recommended to address this soon."
#     ],
#     "Danielle Davis": [
#         "There's a critical concern regarding 'Compliance'-'Non-Compliance Incidents' in Dallas. These are unusually high, primarily influenced by 'Multiple non-compliance incidents'. Immediate attention is required.",
#         "It's important to note that 'Compliance'-'Non-Compliance Incidents' in Dallas are above expected levels, majorly due to 'Upcoming regulatory changes'. It's recommended to address this soon.",
#         "There's a critical concern regarding 'Compliance'-'Regulatory Updates' in Dallas. These are unusually high, primarily influenced by 'Upcoming regulatory changes'. Immediate attention is required.",
#         "There's a critical concern regarding 'Safety Incidents'-'Hazardous Materials' in Dallas. These are unusually high, primarily influenced by 'Hazardous material spill'. Immediate attention is required.",
#         "'Compliance'-'Non-Compliance Incidents' in Dallas have been observed to be slightly higher than usual, influenced by 'Multiple non-compliance incidents'. This should be monitored."
#     ],
#     "Jason Hill": [
#         "There's a critical concern regarding 'Budgets'-'Energy Cost Variance' in Seattle. These are unusually high, primarily influenced by 'Janitorial Budget above 20% mean'. Immediate attention is required.",
#         "There's a critical concern regarding 'Budgets'-'Energy Cost Variance' in Seattle. These are unusually high, primarily influenced by 'Janitorial Budget above 20% mean'. Immediate attention is required.",
#         "There's a critical concern regarding 'Work Orders'-'Completion Rate' in Seattle. These are unusually high, primarily influenced by 'High number of reactive work orders'. Immediate attention is required.",
#         "There's a critical concern regarding 'Energy Usage'-'Energy Efficiency' in Seattle. These are unusually high, primarily influenced by 'High energy usage during peak hours'. Immediate attention is required.",
#         "There's a critical concern regarding 'Work Orders'-'Preventative' in Seattle. These are unusually high, primarily influenced by 'High number of reactive work orders'. Immediate attention is required."
#     ],
#     "Joy Duran": [
#         "There's a critical concern regarding 'Budgets'-'Budget Compliance' in Houston. These are unusually high, primarily influenced by 'Janitorial Budget above 20% mean'. Immediate attention is required.",
#         "It's important to note that 'Budgets'-'Energy Cost Variance' in Houston are above expected levels, majorly due to 'Janitorial Budget above 20% mean'. It's recommended to address this soon.",
#         "There's a critical concern regarding 'Energy Usage'-'Off-Hours' in Houston. These are unusually high, primarily influenced by 'Low energy efficiency'. Immediate attention is required.",
#         "It's important to note that 'Accessibility'-'Public Transport Access' in Houston are above expected levels, majorly due to 'Non-ADA compliant areas'. It's recommended to address this soon.",
#         "'Leases'-'Expiring' in Houston have been observed to be slightly higher than usual, influenced by 'Low renewal rates'. This should be monitored."
#     ],
#     "Gerald Watson": [
#         "It's important to note that 'Work Orders'-'Completion Rate' in Seattle are above expected levels, majorly due to 'High number of reactive work orders'. It's recommended to address this soon.",
#         "There's a critical concern regarding 'Work Orders'-'Reactive' in Seattle. These are unusually high, primarily influenced by 'Completion Rates below 50%'. Immediate attention is required.",
#         "It's important to note that 'Budgets'-'Janitorial Expenses 10% Over Mean' in Seattle are above expected levels, majorly due to 'Energy Costs above 15% mean'. It's recommended to address this soon.",
#         "There's a critical concern regarding 'Leases'-'Occupancy' in Seattle. These are unusually high, primarily influenced by 'Low renewal rates'. Immediate attention is required.",
#         "'Budgets'-'Janitorial Expenses 10% Over Mean' in Seattle have been observed to be slightly higher than usual, influenced by 'Janitorial Budget above 20% mean'. This should be monitored."
#     ],
#     "William Coleman": [
#         "There's a critical concern regarding 'Compliance'-'Non-Compliance Incidents' in Atlanta. These are unusually high, primarily influenced by 'Upcoming regulatory changes'. Immediate attention is required.",
#         "There's a critical concern regarding 'Accessibility'-'Elevator Status' in Atlanta. These are unusually high, primarily influenced by 'Frequent elevator breakdowns'. Immediate attention is required.",
#         "There's a critical concern regarding 'Compliance'-'Non-Compliance Incidents' in Atlanta. These are unusually high, primarily influenced by 'Multiple non-compliance incidents'. Immediate attention is required.",
#         "It's important to note that 'Work Orders'-'Completion Rate' in Atlanta are above expected levels, majorly due to 'High number of reactive work orders'. It's recommended to address this soon.",
#         "There's a critical concern regarding 'Budgets'-'Energy Cost Variance' in Atlanta. These are unusually high, primarily influenced by 'Energy Costs above 15% mean'. Immediate attention is required."
#     ],
#     "Lisa Hoffman": [
#         "There's a critical concern regarding 'Budgets'-'Budget Compliance' in New York. These are unusually high, primarily influenced by 'Janitorial Budget above 20% mean'. Immediate attention is required.",
#         "There's a critical concern regarding 'Work Orders'-'Completion Rate' in New York. These are unusually high, primarily influenced by 'High number of reactive work orders'. Immediate attention is required.",
#         "There's a critical concern regarding 'Energy Usage'-'Off-Hours' in New York. These are unusually high, primarily influenced by 'High energy usage during peak hours'. Immediate attention is required.",
#         "It's important to note that 'Budgets'-'Janitorial Expenses 10% Over Mean' in New York are above expected levels, majorly due to 'Energy Costs above 15% mean'. It's recommended to address this soon.",
#         "There's a critical concern regarding 'Compliance'-'Non-Compliance Incidents' in New York. These are unusually high, primarily influenced by 'Upcoming regulatory changes'. Immediate attention is required."
#     ],
#     "Christian Davis": [
#         "It's important to note that 'Leases'-'Occupancy' in Atlanta are above expected levels, majorly due to 'High number of expiring leases'. It's recommended to address this soon.",
#         "There's a critical concern regarding 'Budgets'-'Budget Compliance' in Atlanta. These are unusually high, primarily influenced by 'Janitorial Budget above 20% mean'. Immediate attention is required.",
#         "There's a critical concern regarding 'Budgets'-'Energy Cost Variance' in Atlanta. These are unusually high, primarily influenced by 'Energy Costs above 15% mean'. Immediate attention is required.",
#         "There's a critical concern regarding 'Work Orders'-'Reactive' in Atlanta. These are unusually high, primarily influenced by 'Completion Rates below 50%'. Immediate attention is required.",
#         "There's a critical concern regarding 'Energy Usage'-'Peak Hours' in Atlanta. These are unusually high, primarily influenced by 'Low energy efficiency'. Immediate attention is required."
#     ],
#     "Bobby George": [
#         "It's important to note that 'Compliance'-'Non-Compliance Incidents' in Dallas are above expected levels, majorly due to 'Upcoming regulatory changes'. It's recommended to address this soon.",
#         "There's a critical concern regarding 'Budgets'-'Budget Compliance' in Dallas. These are unusually high, primarily influenced by 'Energy Costs above 15% mean'. Immediate attention is required.",
#         "It's important to note that 'Accessibility'-'ADA Compliance' in Dallas are above expected levels, majorly due to 'Lack of nearby public transport'. It's recommended to address this soon.",
#         "There's a critical concern regarding 'Work Orders'-'Completion Rate' in Dallas. These are unusually high, primarily influenced by 'High number of reactive work orders'. Immediate attention is required.",
#         "It's important to note that 'Budgets'-'Janitorial Expenses 10% Over Mean' in Dallas are above expected levels, majorly due to 'Janitorial Budget above 20% mean'. It's recommended to address this soon."
#     ],
#     "Charles Love": [
#         "'Leases'-'Occupancy' in Dallas have been observed to be slightly higher than usual, influenced by 'High number of expiring leases'. This should be monitored.",
#         "There's a critical concern regarding 'Compliance'-'Compliance Score' in Dallas. These are unusually high, primarily influenced by 'Multiple non-compliance incidents'. Immediate attention is required.",
#         "'Leases'-'Renewal Rate' in Dallas have been observed to be slightly higher than usual, influenced by 'High number of expiring leases'. This should be monitored.",
#         "'Budgets'-'Janitorial Expenses 10% Over Mean' in Dallas are in line with expectations but are influenced by 'Energy Costs above 15% mean'. No immediate action is required, but it's good to be aware.",
#         "'Work Orders'-'Completion Rate' in Dallas are in line with expectations but are influenced by 'Completion Rates below 50%'. No immediate action is required, but it's good to be aware."
#     ],
#     "Eugene Scott": [
#         "There's a critical concern regarding 'Leases'-'Occupancy' in San Francisco. These are unusually high, primarily influenced by 'High number of expiring leases'. Immediate attention is required.",
#         "There's a critical concern regarding 'Compliance'-'Non-Compliance Incidents' in San Francisco. These are unusually high, primarily influenced by 'Multiple non-compliance incidents'. Immediate attention is required.",
#         "There's a critical concern regarding 'Compliance'-'Regulatory Updates' in San Francisco. These are unusually high, primarily influenced by 'Multiple non-compliance incidents'. Immediate attention is required.",
#         "It's important to note that 'Budgets'-'Energy Cost Variance' in San Francisco are above expected levels, majorly due to 'Energy Costs above 15% mean'. It's recommended to address this soon.",
#         "It's important to note that 'Work Orders'-'Reactive' in San Francisco are above expected levels, majorly due to 'Completion Rates below 50%'. It's recommended to address this soon."
#     ],
#     "Karen Heath": [
#         "There's a critical concern regarding 'Work Orders'-'Preventative' in Seattle. These are unusually high, primarily influenced by 'High number of reactive work orders'. Immediate attention is required.",
#         "There's a critical concern regarding 'Work Orders'-'Completion Rate' in Seattle. These are unusually high, primarily influenced by 'High number of reactive work orders'. Immediate attention is required.",
#         "There's a critical concern regarding 'Budgets'-'Energy Cost Variance' in Seattle. These are unusually high, primarily influenced by 'Janitorial Budget above 20% mean'. Immediate attention is required.",
#         "There's a critical concern regarding 'Budgets'-'Energy Cost Variance' in Seattle. These are unusually high, primarily influenced by 'Janitorial Budget above 20% mean'. Immediate attention is required.",
#         "There's a critical concern regarding 'Energy Usage'-'Energy Efficiency' in Seattle. These are unusually high, primarily influenced by 'High energy usage during peak hours'. Immediate attention is required."
#     ],
#     "Andrea Valdez": [
#         "There's a critical concern regarding 'Budgets'-'Energy Cost Variance' in Boston. These are unusually high, primarily influenced by 'Janitorial Budget above 20% mean'. Immediate attention is required.",
#         "There's a critical concern regarding 'Budgets'-'Janitorial Expenses 10% Over Mean' in Boston. These are unusually high, primarily influenced by 'Energy Costs above 15% mean'. Immediate attention is required.",
#         "There's a critical concern regarding 'Energy Usage'-'Energy Efficiency' in Boston. These are unusually high, primarily influenced by 'High energy usage during peak hours'. Immediate attention is required.",
#         "There's a critical concern regarding 'Budgets'-'Budget Compliance' in Boston. These are unusually high, primarily influenced by 'Energy Costs above 15% mean'. Immediate attention is required.",
#         "It's important to note that 'Compliance'-'Compliance Score' in Boston are above expected levels, majorly due to 'Multiple non-compliance incidents'. It's recommended to address this soon."
#     ],
#     "Robin Mclaughlin": [
#         "There's a critical concern regarding 'Leases'-'Expiring' in San Francisco. These are unusually high, primarily influenced by 'High number of expiring leases'. Immediate attention is required.",
#         "It's important to note that 'Leases'-'Occupancy' in San Francisco are above expected levels, majorly due to 'High number of expiring leases'. It's recommended to address this soon.",
#         "'Leases'-'Occupancy' in San Francisco have been observed to be slightly higher than usual, influenced by 'High number of expiring leases'. This should be monitored.",
#         "It's important to note that 'Work Orders'-'Reactive' in San Francisco are above expected levels, majorly due to 'Completion Rates below 50%'. It's recommended to address this soon.",
#         "'Tenant Satisfaction'-'Amenities Feedback' in San Francisco have been observed to be slightly higher than usual, influenced by 'Multiple noise complaints'. This should be monitored."
#     ],
#     "Craig Rogers": [
#         "There's a critical concern regarding 'Compliance'-'Compliance Score' in San Francisco. These are unusually high, primarily influenced by 'Upcoming regulatory changes'. Immediate attention is required.",
#         "There's a critical concern regarding 'Leases'-'Occupancy' in San Francisco. These are unusually high, primarily influenced by 'High number of expiring leases'. Immediate attention is required.",
#         "There's a critical concern regarding 'Leases'-'Expiring' in San Francisco. These are unusually high, primarily influenced by 'High number of expiring leases'. Immediate attention is required.",
#         "It's important to note that 'Budgets'-'Budget Compliance' in San Francisco are above expected levels, majorly due to 'Energy Costs above 15% mean'. It's recommended to address this soon.",
#         "There's a critical concern regarding 'Accessibility'-'Public Transport Access' in San Francisco. These are unusually high, primarily influenced by 'Lack of nearby public transport'. Immediate attention is required."
#     ],
#     "Jesse Lucas": [
#         "There's a critical concern regarding 'Energy Usage'-'Peak Hours' in Atlanta. These are unusually high, primarily influenced by 'Low energy efficiency'. Immediate attention is required.",
#         "It's important to note that 'Leases'-'Occupancy' in Atlanta are above expected levels, majorly due to 'High number of expiring leases'. It's recommended to address this soon.",
#         "There's a critical concern regarding 'Budgets'-'Budget Compliance' in Atlanta. These are unusually high, primarily influenced by 'Janitorial Budget above 20% mean'. Immediate attention is required.",
#         "There's a critical concern regarding 'Budgets'-'Energy Cost Variance' in Atlanta. These are unusually high, primarily influenced by 'Energy Costs above 15% mean'. Immediate attention is required.",
#         "There's a critical concern regarding 'Work Orders'-'Reactive' in Atlanta. These are unusually high, primarily influenced by 'Completion Rates below 50%'. Immediate attention is required."
#     ],
#     "Anna Gibson": [
#         "There's a critical concern regarding 'Budgets'-'Budget Compliance' in New York. These are unusually high, primarily influenced by 'Energy Costs above 15% mean'. Immediate attention is required.",
#         "There's a critical concern regarding 'Tenant Satisfaction'-'Amenities Feedback' in New York. These are unusually high, primarily influenced by 'Negative amenities feedback'. Immediate attention is required.",
#         "It's important to note that 'Work Orders'-'Completion Rate' in New York are above expected levels, majorly due to 'High number of reactive work orders'. It's recommended to address this soon.",
#         "It's important to note that 'Budgets'-'Budget Compliance' in New York are above expected levels, majorly due to 'Energy Costs above 15% mean'. It's recommended to address this soon.",
#         "'Leases'-'Occupancy' in New York have been observed to be slightly higher than usual, influenced by 'High number of expiring leases'. This should be monitored."
#     ],
#     "Micheal Clark": [
#         "There's a critical concern regarding 'Budgets'-'Energy Cost Variance' in Boston. These are unusually high, primarily influenced by 'Janitorial Budget above 20% mean'. Immediate attention is required.",
#         "There's a critical concern regarding 'Budgets'-'Janitorial Expenses 10% Over Mean' in Boston. These are unusually high, primarily influenced by 'Energy Costs above 15% mean'. Immediate attention is required.",
#         "There's a critical concern regarding 'Energy Usage'-'Energy Efficiency' in Boston. These are unusually high, primarily influenced by 'High energy usage during peak hours'. Immediate attention is required.",
#         "'Leases'-'Occupancy' in Boston have been observed to be slightly higher than usual, influenced by 'High number of expiring leases'. This should be monitored.",
#         "There's a critical concern regarding 'Work Orders'-'Completion Rate' in Boston. These are unusually high, primarily influenced by 'High number of reactive work orders'. Immediate attention is required."
#     ],
#     "Tiffany Hernandez": [
#         "'Leases'-'Occupancy' in Dallas have been observed to be slightly higher than usual, influenced by 'High number of expiring leases'. This should be monitored.",
#         "There's a critical concern regarding 'Compliance'-'Compliance Score' in Dallas. These are unusually high, primarily influenced by 'Multiple non-compliance incidents'. Immediate attention is required.",
#         "'Leases'-'Renewal Rate' in Dallas have been observed to be slightly higher than usual, influenced by 'High number of expiring leases'. This should be monitored.",
#         "'Budgets'-'Janitorial Expenses 10% Over Mean' in Dallas are in line with expectations but are influenced by 'Energy Costs above 15% mean'. No immediate action is required, but it's good to be aware.",
#         "'Work Orders'-'Preventative' in Dallas are in line with expectations but are influenced by 'Completion Rates below 50%'. No immediate action is required, but it's good to be aware."
#     ],
#     "Tammy Anderson": [
#         "There's a critical concern regarding 'Budgets'-'Budget Compliance' in Houston. These are unusually high, primarily influenced by 'Janitorial Budget above 20% mean'. Immediate attention is required.",
#         "It's important to note that 'Leases'-'Occupancy' in Houston are above expected levels, majorly due to 'Low renewal rates'. It's recommended to address this soon.",
#         "It's important to note that 'Budgets'-'Janitorial Expenses 10% Over Mean' in Houston are above expected levels, majorly due to 'Energy Costs above 15% mean'. It's recommended to address this soon.",
#         "It's important to note that 'Energy Usage'-'Energy Efficiency' in Houston are above expected levels, majorly due to 'High energy usage during peak hours'. It's recommended to address this soon.",
#         "It's important to note that 'Energy Usage'-'Energy Efficiency' in Houston are above expected levels, majorly due to 'High energy usage during peak hours'. It's recommended to address this soon."
#     ],
#     "Ariel Miller": [
#         "It's important to note that 'Leases'-'Occupancy' in Atlanta are above expected levels, majorly due to 'High number of expiring leases'. It's recommended to address this soon.",
#         "There's a critical concern regarding 'Budgets'-'Energy Cost Variance' in Atlanta. These are unusually high, primarily influenced by 'Janitorial Budget above 20% mean'. Immediate attention is required.",
#         "It's important to note that 'Leases'-'Occupancy' in Atlanta are above expected levels, majorly due to 'Low renewal rates'. It's recommended to address this soon.",
#         "It's important to note that 'Leases'-'Expiring' in Atlanta are above expected levels, majorly due to 'High number of expiring leases'. It's recommended to address this soon.",
#         "It's important to note that 'Budgets'-'Janitorial Expenses 10% Over Mean' in Atlanta are above expected levels, majorly due to 'Energy Costs above 15% mean'. It's recommended to address this soon."
#     ],
#     "Mary Yang": [
#         "There's a critical concern regarding 'Budgets'-'Janitorial Expenses 10% Over Mean' in New York. These are unusually high, primarily influenced by 'Energy Costs above 15% mean'. Immediate attention is required.",
#         "There's a critical concern regarding 'Leases'-'Renewal Rate' in New York. These are unusually high, primarily influenced by 'High number of expiring leases'. Immediate attention is required.",
#         "There's a critical concern regarding 'Energy Usage'-'Energy Efficiency' in New York. These are unusually high, primarily influenced by 'High energy usage during peak hours'. Immediate attention is required.",
#         "It's important to note that 'Leases'-'Renewal Rate' in New York are above expected levels, majorly due to 'High number of expiring leases'. It's recommended to address this soon.",
#         "'Work Orders'-'Completion Rate' in New York have been observed to be slightly higher than usual, influenced by 'High number of reactive work orders'. This should be monitored."
#     ],
#     "Lauren Bryan": [
#         "There's a critical concern regarding 'Leases'-'Occupancy' in Seattle. These are unusually high, primarily influenced by 'High number of expiring leases'. Immediate attention is required.",
#         "It's important to note that 'Budgets'-'Janitorial Expenses 10% Over Mean' in Seattle are above expected levels, majorly due to 'Janitorial Budget above 20% mean'. It's recommended to address this soon.",
#         "It's important to note that 'Budgets'-'Energy Cost Variance' in Seattle are above expected levels, majorly due to 'Janitorial Budget above 20% mean'. It's recommended to address this soon.",
#         "There's a critical concern regarding 'Work Orders'-'Completion Rate' in Seattle. These are unusually high, primarily influenced by 'High number of reactive work orders'. Immediate attention is required.",
#         "It's important to note that 'Energy Usage'-'Off-Hours' in Seattle are above expected levels, majorly due to 'High energy usage during peak hours'. It's recommended to address this soon."
#     ],
#     "Jasmine Johnson": [
#         "There's a critical concern regarding 'Energy Usage'-'Energy Efficiency' in Boston. These are unusually high, primarily influenced by 'High energy usage during peak hours'. Immediate attention is required.",
#         "There's a critical concern regarding 'Leases'-'Occupancy' in Boston. These are unusually high, primarily influenced by 'Low renewal rates'. Immediate attention is required.",
#         "There's a critical concern regarding 'Compliance'-'Compliance Score' in Boston. These are unusually high, primarily influenced by 'Multiple non-compliance incidents'. Immediate attention is required.",
#         "There's a critical concern regarding 'Compliance'-'Regulatory Updates' in Boston. These are unusually high, primarily influenced by 'Multiple non-compliance incidents'. Immediate attention is required.",
#         "'Budgets'-'Budget Compliance' in Boston have been observed to be slightly higher than usual, influenced by 'Janitorial Budget above 20% mean'. This should be monitored."
#     ],
#     "Joshua Williams": [
#         "There's a critical concern regarding 'Work Orders'-'Completion Rate' in San Francisco. These are unusually high, primarily influenced by 'High number of reactive work orders'. Immediate attention is required.",
#         "There's a critical concern regarding 'Budgets'-'Energy Cost Variance' in San Francisco. These are unusually high, primarily influenced by 'Energy Costs above 15% mean'. Immediate attention is required.",
#         "There's a critical concern regarding 'Compliance'-'Non-Compliance Incidents' in San Francisco. These are unusually high, primarily influenced by 'Upcoming regulatory changes'. Immediate attention is required.",
#         "It's important to note that 'Leases'-'Occupancy' in San Francisco are above expected levels, majorly due to 'Low renewal rates'. It's recommended to address this soon.",
#         "It's important to note that 'Leases'-'Renewal Rate' in San Francisco are above expected levels, majorly due to 'High number of expiring leases'. It's recommended to address this soon."
#     ],
#     "Scott Palmer": [
# ...
#         "It's important to note that 'Leases'-'Expiring' in Seattle are above expected levels, majorly due to 'Low renewal rates'. It's recommended to address this soon.",
#         "'Energy Usage'-'Peak Hours' in Seattle have been observed to be slightly higher than usual, influenced by 'High energy usage during peak hours'. This should be monitored."
#     ],
#     "Whitney Richards": [
#         "There's a critical concern regarding 'Energy Usage'-'Energy Efficiency' in Seattle. These are unusually high, primarily influenced by 'High energy usage during peak hours'. Immediate attention is required.",
#         "There's a critical concern regarding 'Budgets'-'Energy Cost Variance' in Seattle. These are unusually high, primarily influenced by 'Janitorial Budget above 20% mean'. Immediate attention is required.",
#         "There's a critical concern regarding 'Budgets'-'Energy Cost Variance' in Seattle. These are unusually high, primarily influenced by 'Janitorial Budget above 20% mean'. Immediate attention is required.",
#         "There's a critical concern regarding 'Work Orders'-'Completion Rate' in Seattle. These are unusually high, primarily influenced by 'High number of reactive work orders'. Immediate attention is required.",
#         "There's a critical concern regarding 'Work Orders'-'Preventative' in Seattle. These are unusually high, primarily influenced by 'High number of reactive work orders'. Immediate attention is required."
#     ],
#     "Dr. Karen Ortega MD": [
#         "There's a critical concern regarding 'Compliance'-'Non-Compliance Incidents' in Houston. These are unusually high, primarily influenced by 'Upcoming regulatory changes'. Immediate attention is required.",
#         "It's important to note that 'Compliance'-'Compliance Score' in Houston are above expected levels, majorly due to 'Upcoming regulatory changes'. It's recommended to address this soon.",
#         "It's important to note that 'Budgets'-'Budget Compliance' in Houston are above expected levels, majorly due to 'Janitorial Budget above 20% mean'. It's recommended to address this soon.",
#         "It's important to note that 'Compliance'-'Non-Compliance Incidents' in Houston are above expected levels, majorly due to 'Upcoming regulatory changes'. It's recommended to address this soon.",
#         "There's a critical concern regarding 'Compliance'-'Compliance Score' in Houston. These are unusually high, primarily influenced by 'Multiple non-compliance incidents'. Immediate attention is required."
#     ],
#     "Kenneth Johnson": [
#         "It's important to note that 'Leases'-'Occupancy' in Los Angeles are above expected levels, majorly due to 'High number of expiring leases'. It's recommended to address this soon.",
#         "It's important to note that 'Leases'-'Occupancy' in Los Angeles are above expected levels, majorly due to 'High number of expiring leases'. It's recommended to address this soon.",
#         "There's a critical concern regarding 'Leases'-'Expiring' in Los Angeles. These are unusually high, primarily influenced by 'Low renewal rates'. Immediate attention is required.",
#         "It's important to note that 'Budgets'-'Janitorial Expenses 10% Over Mean' in Los Angeles are above expected levels, majorly due to 'Janitorial Budget above 20% mean'. It's recommended to address this soon.",
#         "It's important to note that 'Safety Incidents'-'Hazardous Materials' in Los Angeles are above expected levels, majorly due to 'Recent fire drill failure'. It's recommended to address this soon."
#     ],
#     "John Vega": [
#         "There's a critical concern regarding 'Leases'-'Renewal Rate' in Chicago. These are unusually high, primarily influenced by 'High number of expiring leases'. Immediate attention is required.",
#         "It's important to note that 'Budgets'-'Janitorial Expenses 10% Over Mean' in Chicago are above expected levels, majorly due to 'Energy Costs above 15% mean'. It's recommended to address this soon.",
#         "There's a critical concern regarding 'Energy Usage'-'Peak Hours' in Chicago. These are unusually high, primarily influenced by 'High energy usage during peak hours'. Immediate attention is required.",
#         "It's important to note that 'Work Orders'-'Preventative' in Chicago are above expected levels, majorly due to 'High number of reactive work orders'. It's recommended to address this soon.",
#         "It's important to note that 'Budgets'-'Energy Cost Variance' in Chicago are above expected levels, majorly due to 'Janitorial Budget above 20% mean'. It's recommended to address this soon."
#     ],
#     "Kayla Gutierrez": [
#         "It's important to note that 'Energy Usage'-'Energy Efficiency' in San Francisco are above expected levels, majorly due to 'High energy usage during peak hours'. It's recommended to address this soon.",
#         "There's a critical concern regarding 'Energy Usage'-'Peak Hours' in San Francisco. These are unusually high, primarily influenced by 'High energy usage during peak hours'. Immediate attention is required.",
#         "It's important to note that 'Budgets'-'Janitorial Expenses 10% Over Mean' in San Francisco are above expected levels, majorly due to 'Janitorial Budget above 20% mean'. It's recommended to address this soon.",
#         "It's important to note that 'Budgets'-'Energy Cost Variance' in San Francisco are above expected levels, majorly due to 'Janitorial Budget above 20% mean'. It's recommended to address this soon.",
#         "There's a critical concern regarding 'Compliance'-'Non-Compliance Incidents' in San Francisco. These are unusually high, primarily influenced by 'Upcoming regulatory changes'. Immediate attention is required."
#     ],
#     "Mary Byrd": [
#         "'Tenant Satisfaction'-'Lease Satisfaction' in Chicago have been observed to be slightly higher than usual, influenced by 'Multiple noise complaints'. This should be monitored.",
#         "It's important to note that 'Work Orders'-'Preventative' in Chicago are above expected levels, majorly due to 'High number of reactive work orders'. It's recommended to address this soon.",
#         "There's a critical concern regarding 'Work Orders'-'Completion Rate' in Chicago. These are unusually high, primarily influenced by 'Completion Rates below 50%'. Immediate attention is required.",
#         "It's important to note that 'Compliance'-'Regulatory Updates' in Chicago are above expected levels, majorly due to 'Multiple non-compliance incidents'. It's recommended to address this soon.",
#         "There's a critical concern regarding 'Energy Usage'-'Peak Hours' in Chicago. These are unusually high, primarily influenced by 'High energy usage during peak hours'. Immediate attention is required."
#     ],
#     "Albert Anderson": [
#         "'Work Orders'-'Completion Rate' in Seattle have been observed to be slightly higher than usual, influenced by 'High number of reactive work orders'. This should be monitored.",
#         "There's a critical concern regarding 'Budgets'-'Budget Compliance' in Seattle. These are unusually high, primarily influenced by 'Energy Costs above 15% mean'. Immediate attention is required.",
#         "There's a critical concern regarding 'Energy Usage'-'Peak Hours' in Seattle. These are unusually high, primarily influenced by 'High energy usage during peak hours'. Immediate attention is required.",
#         "It's important to note that 'Budgets'-'Janitorial Expenses 10% Over Mean' in Seattle are above expected levels, majorly due to 'Energy Costs above 15% mean'. It's recommended to address this soon.",
#         "There's a critical concern regarding 'Compliance'-'Non-Compliance Incidents' in Seattle. These are unusually high, primarily influenced by 'Multiple non-compliance incidents'. Immediate attention is required."
#     ],
#     "Steven Roberson": [
#         "There's a critical concern regarding 'Energy Usage'-'Off-Hours' in Dallas. These are unusually high, primarily influenced by 'Low energy efficiency'. Immediate attention is required.",
#         "'Energy Usage'-'Peak Hours' in Dallas have been observed to be slightly higher than usual, influenced by 'Low energy efficiency'. This should be monitored.",
#         "It's important to note that 'Budgets'-'Janitorial Expenses 10% Over Mean' in Dallas are above expected levels, majorly due to 'Energy Costs above 15% mean'. It's recommended to address this soon.",
#         "There's a critical concern regarding 'Work Orders'-'Completion Rate' in Dallas. These are unusually high, primarily influenced by 'High number of reactive work orders'. Immediate attention is required.",
#         "'Budgets'-'Janitorial Expenses 10% Over Mean' in Dallas have been observed to be slightly higher than usual, influenced by 'Janitorial Budget above 20% mean'. This should be monitored."
#     ],
#     "Carlos Montgomery": [
#         "It's important to note that 'Work Orders'-'Completion Rate' in Seattle are above expected levels, majorly due to 'High number of reactive work orders'. It's recommended to address this soon.",
#         "There's a critical concern regarding 'Work Orders'-'Reactive' in Seattle. These are unusually high, primarily influenced by 'Completion Rates below 50%'. Immediate attention is required.",
#         "It's important to note that 'Leases'-'Renewal Rate' in Seattle are above expected levels, majorly due to 'High number of expiring leases'. It's recommended to address this soon.",
#         "It's important to note that 'Budgets'-'Budget Compliance' in Seattle are above expected levels, majorly due to 'Janitorial Budget above 20% mean'. It's recommended to address this soon.",
#         "'Work Orders'-'Preventative' in Seattle have been observed to be slightly higher than usual, influenced by 'Completion Rates below 50%'. This should be monitored."
#     ],
#     "Kaitlin Campbell": [
#         "There's a critical concern regarding 'Energy Usage'-'Off-Hours' in New York. These are unusually high, primarily influenced by 'Low energy efficiency'. Immediate attention is required.",
#         "It's important to note that 'Energy Usage'-'Off-Hours' in New York are above expected levels, majorly due to 'Low energy efficiency'. It's recommended to address this soon.",
#         "It's important to note that 'Energy Usage'-'Peak Hours' in New York are above expected levels, majorly due to 'Low energy efficiency'. It's recommended to address this soon.",
#         "There's a critical concern regarding 'Work Orders'-'Reactive' in New York. These are unusually high, primarily influenced by 'High number of reactive work orders'. Immediate attention is required.",
#         "It's important to note that 'Budgets'-'Energy Cost Variance' in New York are above expected levels, majorly due to 'Janitorial Budget above 20% mean'. It's recommended to address this soon."
#     ],
#     "Brian Diaz": [
#         "There's a critical concern regarding 'Work Orders'-'Reactive' in Dallas. These are unusually high, primarily influenced by 'High number of reactive work orders'. Immediate attention is required.",
#         "'Tenant Satisfaction'-'Amenities Feedback' in Dallas have been observed to be slightly higher than usual, influenced by 'Low lease satisfaction scores'. This should be monitored.",
#         "There's a critical concern regarding 'Compliance'-'Regulatory Updates' in Dallas. These are unusually high, primarily influenced by 'Upcoming regulatory changes'. Immediate attention is required.",
#         "There's a critical concern regarding 'Compliance'-'Regulatory Updates' in Dallas. These are unusually high, primarily influenced by 'Upcoming regulatory changes'. Immediate attention is required.",
#         "It's important to note that 'Energy Usage'-'Energy Efficiency' in Dallas are above expected levels, majorly due to 'High energy usage during peak hours'. It's recommended to address this soon."
#     ],
#     "Mrs. Regina Armstrong": [
#         "There's a critical concern regarding 'Budgets'-'Energy Cost Variance' in Miami. These are unusually high, primarily influenced by 'Janitorial Budget above 20% mean'. Immediate attention is required.",
#         "There's a critical concern regarding 'Leases'-'Expiring' in Miami. These are unusually high, primarily influenced by 'High number of expiring leases'. Immediate attention is required.",
#         "It's important to note that 'Budgets'-'Janitorial Expenses 10% Over Mean' in Miami are above expected levels, majorly due to 'Energy Costs above 15% mean'. It's recommended to address this soon.",
#         "There's a critical concern regarding 'Compliance'-'Compliance Score' in Miami. These are unusually high, primarily influenced by 'Upcoming regulatory changes'. Immediate attention is required.",
#         "There's a critical concern regarding 'Compliance'-'Non-Compliance Incidents' in Miami. These are unusually high, primarily influenced by 'Multiple non-compliance incidents'. Immediate attention is required."
#     ],
#     "Kathleen Hamilton": [
#         "There's a critical concern regarding 'Work Orders'-'Reactive' in Dallas. These are unusually high, primarily influenced by 'High number of reactive work orders'. Immediate attention is required.",
#         "It's important to note that 'Energy Usage'-'Energy Efficiency' in Dallas are above expected levels, majorly due to 'High energy usage during peak hours'. It's recommended to address this soon.",
#         "It's important to note that 'Budgets'-'Janitorial Expenses 10% Over Mean' in Dallas are above expected levels, majorly due to 'Janitorial Budget above 20% mean'. It's recommended to address this soon.",
#         "There's a critical concern regarding 'Leases'-'Occupancy' in Dallas. These are unusually high, primarily influenced by 'Low renewal rates'. Immediate attention is required.",
#         "There's a critical concern regarding 'Compliance'-'Regulatory Updates' in Dallas. These are unusually high, primarily influenced by 'Upcoming regulatory changes'. Immediate attention is required."
#     ],
#     "Lisa Valdez": [
#         "It's important to note that 'Compliance'-'Non-Compliance Incidents' in Houston are above expected levels, majorly due to 'Multiple non-compliance incidents'. It's recommended to address this soon.",
#         "There's a critical concern regarding 'Safety Incidents'-'Hazardous Materials' in Houston. These are unusually high, primarily influenced by 'Recent fire drill failure'. Immediate attention is required.",
#         "There's a critical concern regarding 'Compliance'-'Compliance Score' in Houston. These are unusually high, primarily influenced by 'Upcoming regulatory changes'. Immediate attention is required.",
#         "'Compliance'-'Non-Compliance Incidents' in Houston have been observed to be slightly higher than usual, influenced by 'Multiple non-compliance incidents'. This should be monitored.",
#         "'Compliance'-'Non-Compliance Incidents' in Houston have been observed to be slightly higher than usual, influenced by 'Multiple non-compliance incidents'. This should be monitored."
#     ],
#     "Casey Barry": [
#         "There's a critical concern regarding 'Leases'-'Renewal Rate' in Dallas. These are unusually high, primarily influenced by 'High number of expiring leases'. Immediate attention is required.",
#         "There's a critical concern regarding 'Leases'-'Renewal Rate' in Dallas. These are unusually high, primarily influenced by 'High number of expiring leases'. Immediate attention is required.",
#         "There's a critical concern regarding 'Leases'-'Expiring' in Dallas. These are unusually high, primarily influenced by 'Low renewal rates'. Immediate attention is required.",
#         "It's important to note that 'Leases'-'Occupancy' in Dallas are above expected levels, majorly due to 'High number of expiring leases'. It's recommended to address this soon.",
#         "There's a critical concern regarding 'Work Orders'-'Preventative' in Dallas. These are unusually high, primarily influenced by 'High number of reactive work orders'. Immediate attention is required."
#     ]
# }
